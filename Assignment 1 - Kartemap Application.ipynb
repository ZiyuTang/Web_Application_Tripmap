# %% [markdown]
# # Kartemap Application

# %% [markdown]
# Ziyu Tang, Xinlan Wu

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go

from graph.shortest_path import Dijkstra
from graph.network import Network

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Prepare data

# %% [markdown]
# #### Read data

# %%
df = pd.read_csv('data/final flight data with population.csv')
city_info = pd.read_csv('data/city_info.csv')

# %%
city_info.head()
# Out:
#        City Population                                              Links  \
# 0  Aberdeen    unknown  https://www.britannica.com/place/Aberdeen-Mary...
# 1   Abilene    172,060    https://www.britannica.com/place/Abilene-Kansas
# 2     Akron    703,479        https://www.britannica.com/place/Akron-Ohio
# 3   Alamosa    unknown           https://www.britannica.com/place/Alamosa
# 4    Albany    880,381    https://www.britannica.com/place/Albany-Georgia
#
#                                           photo_link
# 0  https://cdn.britannica.com/78/117478-050-6A0BF...
# 1  https://cdn.britannica.com/60/186160-050-0C856...
# 2  https://cdn.britannica.com/91/116691-004-37CFF...
# 3  https://cdn.britannica.com/30/172530-050-7C83F...
# 4  https://cdn.britannica.com/47/121747-050-5959B...

# %%
df = df.sort_values(['Source_City','Destination_City'])
df['Source_Popution'] = df['Source_Popution'].replace(np.nan, 'unknown', regex=True)
df['Destination_Popution'] = df['Destination_Popution'].replace(np.nan, 'unknown', regex=True)

df.head()
# Out:
#      Airline Airline ID Source airport  Source airport ID Destination airport  \
# 3612      DL       2009            ABR               5714                 MSP
# 518       AA         24            ABI               3718                 DFW
# 8946      US       5265            ABI               3718                 DFW
# 2576      AS        439            ADK               5959                 ANC
# 298       8D       1109            AKK               7160                 ADQ
#
#       Destination airport ID Codeshare  Stops    Equipment  \
# 3612                    3858         Y      0          CRJ
# 518                     3670         Y      0  ERD ER4 CRJ
# 8946                    3670       NaN      0      ERD ER4
# 2576                    3774       NaN      0      734 73Q
# 298                     3531       NaN      0          CNA
#
#                  Source_Airport  Source_City  Source_Latitude  \
# 3612  Aberdeen Regional Airport     Aberdeen        45.449100
# 518    Abilene Regional Airport      Abilene        32.411301
# 8946   Abilene Regional Airport      Abilene        32.411301
# 2576               Adak Airport  Adak Island        51.877998
# 298              Akhiok Airport       Akhiok        56.938702
#
#       Source_Longitude  Source_Altitude  \
# 3612        -98.421799             1302
# 518         -99.681900             1791
# 8946        -99.681900             1791
# 2576       -176.645996               18
# 298        -154.182999               44
#
#                                     Destination_Airport   Destination_City  \
# 3612  Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 518             Dallas Fort Worth International Airport  Dallas-Fort Worth
# 8946            Dallas Fort Worth International Airport  Dallas-Fort Worth
# 2576        Ted Stevens Anchorage International Airport          Anchorage
# 298                                      Kodiak Airport             Kodiak
#
#       Destination_Latitude  Destination_Longitude  Destination_Altitude  \
# 3612             44.882000             -93.221802                   841
# 518              32.896801             -97.038002                   607
# 8946             32.896801             -97.038002                   607
# 2576             61.174400            -149.996002                   152
# 298              57.750000            -152.494003                    78
#
#                               Source_geometry  \
# 3612  (45.44910049438477, -98.42179870605469)
# 518       (32.4113006592, -99.68190002440001)
# 8946      (32.4113006592, -99.68190002440001)
# 2576    (51.87799835205078, -176.64599609375)
# 298           (56.9387016296, -154.182998657)
#
#                            Destination_geometry     distance Source_Popution  \
# 3612                       (44.882, -93.221802)   413.573939         unknown
# 518                     (32.896801, -97.038002)   253.808916         172,060
# 8946                    (32.896801, -97.038002)   253.808916         172,060
# 2576  (61.174400329589844, -149.99600219726562)  1918.725845         unknown
# 298                       (57.75, -152.4940033)   136.025819         unknown
#
#      Destination_Popution
# 3612            3,654,908
# 518               unknown
# 8946              unknown
# 2576              396,317
# 298               unknown

# %%
df_airport_1 = df[['Source_Airport','Source_City','Source_Latitude','Source_Longitude']]
df_airport_1 = df_airport_1.rename(columns={'Source_Airport':'Airport','Source_City':'City','Source_Latitude':'Latitude','Source_Longitude':'Longitude'})
df_airport_2 = df[['Destination_Airport','Destination_City','Destination_Latitude','Destination_Longitude']]
df_airport_2 = df_airport_2.rename(columns={'Destination_Airport':'Airport','Destination_City':'City','Destination_Latitude':'Latitude','Destination_Longitude':'Longitude'})
df_airport = pd.concat([df_airport_1,df_airport_2])
df_airport = df_airport.drop_duplicates(subset=['Airport','City'])
df_airport.head()
# Out:
#                             Airport         City   Latitude   Longitude
# 3612      Aberdeen Regional Airport     Aberdeen  45.449100  -98.421799
# 518        Abilene Regional Airport      Abilene  32.411301  -99.681900
# 2576                   Adak Airport  Adak Island  51.877998 -176.645996
# 298                  Akhiok Airport       Akhiok  56.938702 -154.182999
# 2345  Akron Canton Regional Airport        Akron  40.916100  -81.442200

# %%
df_city = city_info.copy()

# %% [markdown]
# #### Create a dictionary of airport network

# %%
source_list = df['Source_Airport'].unique()
network_dict = {}
for i in source_list:
    new_df = df[df['Source_Airport'] == i][['Destination_Airport','distance']].set_index('Destination_Airport')
    new_df = new_df.rename(columns={'distance':i})
    dict_ = new_df.to_dict()
    network_dict.update(dict_)

# %% [markdown]
# #### Create relation options between departure city and departure airport

# %%
departure_list = df['Source_City'].unique()
departure_airport_dict = {}
for i in departure_list:
    new_ = df[df['Source_City'] == i]
    departure_airport_dict[i] = new_['Source_Airport'].unique().tolist()

# %% [markdown]
# #### Create relation options between arrival city and arrival airport

# %%
arrival_list = df['Destination_City'].unique()
arrival_airport_dict = {}
for i in arrival_list:
    new_ = df[df['Destination_City'] == i]
    arrival_airport_dict[i] = new_['Destination_Airport'].unique().tolist()

# %% [markdown]
# #### Create a function to read network data

# %%
def read_network_from_file(file_name, delimeter=','):
    """ Read from a file and build a network
    file_name: file to read from
    delimeter: delimeter that separates fields
    """
    cities = list()
    distances = dict()

    f = open(file_name, 'r')
    lines = f.readlines()
    for line in lines:
        fields = line.rstrip().split(delimeter)
        city_1 = fields[0].strip(' ')
        city_2 = fields[1].strip(' ')
        distance = float(fields[2])

        # build the list of cities
        if city_1 not in cities:
            cities.append(city_1)
        if city_2 not in cities:
            cities.append(city_2)

        # build the dictionary based on city distances
        if cities.index(city_1) not in distances.keys():
            distances[cities.index(city_1)] = {cities.index(city_2): distance}
        if cities.index(city_2) not in distances[cities.index(city_1)].keys():
            distances[cities.index(city_1)][cities.index(city_2)] = distance

    return cities, distances

file_name = 'data/flight network.csv'
cities, distances = read_network_from_file(file_name)

# %% [markdown]
# ## App

# %%
[{"label":i,"value":i}for i in df.Source_City.unique()]
# Out:
# [{'label': 'Aberdeen', 'value': 'Aberdeen'},
#  {'label': 'Abilene', 'value': 'Abilene'},
#  {'label': 'Adak Island', 'value': 'Adak Island'},
#  {'label': 'Akhiok', 'value': 'Akhiok'},
#  {'label': 'Akron', 'value': 'Akron'},
#  {'label': 'Akutan', 'value': 'Akutan'},
#  {'label': 'Alakanuk', 'value': 'Alakanuk'},
#  {'label': 'Alamosa', 'value': 'Alamosa'},
#  {'label': 'Albany', 'value': 'Albany'},
#  {'label': 'Albuquerque', 'value': 'Albuquerque'},
#  {'label': 'Alexandria', 'value': 'Alexandria'},
#  {'label': 'Allakaket', 'value': 'Allakaket'},
#  {'label': 'Allentown', 'value': 'Allentown'},
#  {'label': 'Alliance', 'value': 'Alliance'},
#  {'label': 'Alpena', 'value': 'Alpena'},
#  {'label': 'Altoona', 'value': 'Altoona'},
#  {'label': 'Amarillo', 'value': 'Amarillo'},
#  {'label': 'Ambler', 'value': 'Ambler'},
#  {'label': 'Anaktuvuk Pass', 'value': 'Anaktuvuk Pass'},
#  {'label': 'Anchorage', 'value': 'Anchorage'},
#  {'label': 'Aniak', 'value': 'Aniak'},
#  {'label': 'Anvik', 'value': 'Anvik'},
#  {'label': 'Appleton', 'value': 'Appleton'},
#  {'label': 'Arcata CA', 'value': 'Arcata CA'},
#  {'label': 'Arctic Village', 'value': 'Arctic Village'},
#  {'label': 'Asheville', 'value': 'Asheville'},
#  {'label': 'Aspen', 'value': 'Aspen'},
#  {'label': 'Athens', 'value': 'Athens'},
#  {'label': 'Atka', 'value': 'Atka'},
#  {'label': 'Atlanta', 'value': 'Atlanta'},
#  {'label': 'Atlantic City', 'value': 'Atlantic City'},
#  {'label': 'Atqasuk', 'value': 'Atqasuk'},
#  {'label': 'Augusta', 'value': 'Augusta'},
#  {'label': 'Austin', 'value': 'Austin'},
#  {'label': 'BRISTOL', 'value': 'BRISTOL'},
#  {'label': 'Bakersfield', 'value': 'Bakersfield'},
#  {'label': 'Baltimore', 'value': 'Baltimore'},
#  {'label': 'Bangor', 'value': 'Bangor'},
#  {'label': 'Bar Harbor', 'value': 'Bar Harbor'},
#  {'label': 'Barnstable', 'value': 'Barnstable'},
#  {'label': 'Barrow', 'value': 'Barrow'},
#  {'label': 'Barter Island', 'value': 'Barter Island'},
#  {'label': 'Baton Rouge', 'value': 'Baton Rouge'},
#  {'label': 'Beaumont', 'value': 'Beaumont'},
#  {'label': 'Beaver', 'value': 'Beaver'},
#  {'label': 'Beckley', 'value': 'Beckley'},
#  {'label': 'Belleville', 'value': 'Belleville'},
#  {'label': 'Bellingham', 'value': 'Bellingham'},
#  {'label': 'Bemidji', 'value': 'Bemidji'},
#  {'label': 'Bentonville', 'value': 'Bentonville'},
#  {'label': 'Bethel', 'value': 'Bethel'},
#  {'label': 'Bettles', 'value': 'Bettles'},
#  {'label': 'Billings', 'value': 'Billings'},
#  {'label': 'Binghamton', 'value': 'Binghamton'},
#  {'label': 'Birmingham', 'value': 'Birmingham'},
#  {'label': 'Bismarck', 'value': 'Bismarck'},
#  {'label': 'Bloomington', 'value': 'Bloomington'},
#  {'label': 'Boise', 'value': 'Boise'},
#  {'label': 'Boston', 'value': 'Boston'},
#  {'label': 'Bozeman', 'value': 'Bozeman'},
#  {'label': 'Bradford', 'value': 'Bradford'},
#  {'label': 'Brainerd', 'value': 'Brainerd'},
#  {'label': 'Branson', 'value': 'Branson'},
#  {'label': 'Brevig Mission', 'value': 'Brevig Mission'},
#  {'label': 'Brownsville', 'value': 'Brownsville'},
#  {'label': 'Brunswick', 'value': 'Brunswick'},
#  {'label': 'Buckland', 'value': 'Buckland'},
#  {'label': 'Buffalo', 'value': 'Buffalo'},
#  {'label': 'Burbank', 'value': 'Burbank'},
#  {'label': 'Burlington', 'value': 'Burlington'},
#  {'label': 'Bush Field', 'value': 'Bush Field'},
#  {'label': 'Butte', 'value': 'Butte'},
#  {'label': 'Cape Girardeau', 'value': 'Cape Girardeau'},
#  {'label': 'Cape Lisburne', 'value': 'Cape Lisburne'},
#  {'label': 'Carlsbad', 'value': 'Carlsbad'},
#  {'label': 'Casper', 'value': 'Casper'},
#  {'label': 'Cedar City', 'value': 'Cedar City'},
#  {'label': 'Cedar Rapids', 'value': 'Cedar Rapids'},
#  {'label': 'Central', 'value': 'Central'},
#  {'label': 'Chadron', 'value': 'Chadron'},
#  {'label': 'Chalkyitsik', 'value': 'Chalkyitsik'},
#  {'label': 'Champaign', 'value': 'Champaign'},
#  {'label': 'Charleston', 'value': 'Charleston'},
#  {'label': 'Charlotte', 'value': 'Charlotte'},
#  {'label': 'Charlottesville VA', 'value': 'Charlottesville VA'},
#  {'label': 'Chattanooga', 'value': 'Chattanooga'},
#  {'label': 'Chefornak', 'value': 'Chefornak'},
#  {'label': 'Chevak', 'value': 'Chevak'},
#  {'label': 'Cheyenne', 'value': 'Cheyenne'},
#  {'label': 'Chicago', 'value': 'Chicago'},
#  {'label': 'Chico', 'value': 'Chico'},
#  {'label': 'Cincinnati', 'value': 'Cincinnati'},
#  {'label': 'Circle', 'value': 'Circle'},
#  {'label': 'Clarksburg', 'value': 'Clarksburg'},
#  {'label': 'Cleveland', 'value': 'Cleveland'},
#  {'label': 'Cody', 'value': 'Cody'},
#  {'label': 'Cold Bay', 'value': 'Cold Bay'},
#  {'label': 'College Station', 'value': 'College Station'},
#  {'label': 'Colorado Springs', 'value': 'Colorado Springs'},
#  {'label': 'Columbia', 'value': 'Columbia'},
#  {'label': 'Columbus', 'value': 'Columbus'},
#  {'label': 'Columbus Mississippi', 'value': 'Columbus Mississippi'},
#  {'label': 'Cordova', 'value': 'Cordova'},
#  {'label': 'Corpus Christi', 'value': 'Corpus Christi'},
#  {'label': 'Cortez', 'value': 'Cortez'},
#  {'label': 'Crescent City', 'value': 'Crescent City'},
#  {'label': 'Dallas', 'value': 'Dallas'},
#  {'label': 'Dallas-Fort Worth', 'value': 'Dallas-Fort Worth'},
#  {'label': 'Dayton', 'value': 'Dayton'},
#  {'label': 'Daytona Beach', 'value': 'Daytona Beach'},
#  {'label': 'Deadhorse', 'value': 'Deadhorse'},
#  {'label': 'Decatur', 'value': 'Decatur'},
#  {'label': 'Deering', 'value': 'Deering'},
#  {'label': 'Denver', 'value': 'Denver'},
#  {'label': 'Des Moines', 'value': 'Des Moines'},
#  {'label': 'Detroit', 'value': 'Detroit'},
#  {'label': 'Dickinson', 'value': 'Dickinson'},
#  {'label': 'Dillingham', 'value': 'Dillingham'},
#  {'label': 'Dodge City', 'value': 'Dodge City'},
#  {'label': 'Dothan', 'value': 'Dothan'},
#  {'label': 'Du Bois', 'value': 'Du Bois'},
#  {'label': 'Dubuque IA', 'value': 'Dubuque IA'},
#  {'label': 'Duluth', 'value': 'Duluth'},
#  {'label': 'Durango', 'value': 'Durango'},
#  {'label': 'Eastsound', 'value': 'Eastsound'},
#  {'label': 'Eau Claire', 'value': 'Eau Claire'},
#  {'label': 'Eek', 'value': 'Eek'},
#  {'label': 'Egegik', 'value': 'Egegik'},
#  {'label': 'El Dorado', 'value': 'El Dorado'},
#  {'label': 'El Paso', 'value': 'El Paso'},
#  {'label': 'Elfin Cove', 'value': 'Elfin Cove'},
#  {'label': 'Elim', 'value': 'Elim'},
#  {'label': 'Elko', 'value': 'Elko'},
#  {'label': 'Elmira', 'value': 'Elmira'},
#  {'label': 'Emmonak', 'value': 'Emmonak'},
#  {'label': 'Erie', 'value': 'Erie'},
#  {'label': 'Escanaba', 'value': 'Escanaba'},
#  {'label': 'Eugene', 'value': 'Eugene'},
#  {'label': 'Evansville', 'value': 'Evansville'},
#  {'label': 'Fairbanks', 'value': 'Fairbanks'},
#  {'label': 'False Pass', 'value': 'False Pass'},
#  {'label': 'Fargo', 'value': 'Fargo'},
#  {'label': 'Farmington', 'value': 'Farmington'},
#  {'label': 'Fayetteville', 'value': 'Fayetteville'},
#  {'label': 'Flagstaff', 'value': 'Flagstaff'},
#  {'label': 'Flint', 'value': 'Flint'},
#  {'label': 'Florence', 'value': 'Florence'},
#  {'label': 'Fort Lauderdale', 'value': 'Fort Lauderdale'},
#  {'label': 'Fort Leonardwood', 'value': 'Fort Leonardwood'},
#  {'label': 'Fort Myers', 'value': 'Fort Myers'},
#  {'label': 'Fort Smith', 'value': 'Fort Smith'},
#  {'label': 'Fort Wayne', 'value': 'Fort Wayne'},
#  {'label': 'Fort Yukon', 'value': 'Fort Yukon'},
#  {'label': 'Franklin', 'value': 'Franklin'},
#  {'label': 'Fresno', 'value': 'Fresno'},
#  {'label': 'Friday Harbor', 'value': 'Friday Harbor'},
#  {'label': 'Gainesville', 'value': 'Gainesville'},
#  {'label': 'Galena', 'value': 'Galena'},
#  {'label': 'Gambell', 'value': 'Gambell'},
#  {'label': 'Garden City', 'value': 'Garden City'},
#  {'label': 'Gillette', 'value': 'Gillette'},
#  {'label': 'Glasgow', 'value': 'Glasgow'},
#  {'label': 'Glendive', 'value': 'Glendive'},
#  {'label': 'Golovin', 'value': 'Golovin'},
#  {'label': 'Grand Canyon', 'value': 'Grand Canyon'},
#  {'label': 'Grand Forks', 'value': 'Grand Forks'},
#  {'label': 'Grand Island', 'value': 'Grand Island'},
#  {'label': 'Grand Junction', 'value': 'Grand Junction'},
#  {'label': 'Grand Rapids', 'value': 'Grand Rapids'},
#  {'label': 'Great Falls', 'value': 'Great Falls'},
#  {'label': 'Green Bay', 'value': 'Green Bay'},
#  {'label': 'Greensboro', 'value': 'Greensboro'},
#  {'label': 'Greenville', 'value': 'Greenville'},
#  {'label': 'Gulfport', 'value': 'Gulfport'},
#  {'label': 'Gunnison', 'value': 'Gunnison'},
#  {'label': 'Gustavus', 'value': 'Gustavus'},
#  {'label': 'Gwinn', 'value': 'Gwinn'},
#  {'label': 'Hagerstown', 'value': 'Hagerstown'},
#  {'label': 'Haines', 'value': 'Haines'},
#  {'label': 'Hana', 'value': 'Hana'},
#  {'label': 'Hancock', 'value': 'Hancock'},
#  {'label': 'Harlingen', 'value': 'Harlingen'},
#  {'label': 'Harrisburg', 'value': 'Harrisburg'},
#  {'label': 'Harrison', 'value': 'Harrison'},
#  {'label': 'Hattiesburg/Laurel', 'value': 'Hattiesburg/Laurel'},
#  {'label': 'Havre', 'value': 'Havre'},
#  {'label': 'Hayden', 'value': 'Hayden'},
#  {'label': 'Healy', 'value': 'Healy'},
#  {'label': 'Helena', 'value': 'Helena'},
#  {'label': 'Hibbing', 'value': 'Hibbing'},
#  {'label': 'Hilo', 'value': 'Hilo'},
#  {'label': 'Hilton Head Island', 'value': 'Hilton Head Island'},
#  {'label': 'Hobbs', 'value': 'Hobbs'},
#  {'label': 'Holy Cross', 'value': 'Holy Cross'},
#  {'label': 'Homer', 'value': 'Homer'},
#  {'label': 'Honolulu', 'value': 'Honolulu'},
#  {'label': 'Hoonah', 'value': 'Hoonah'},
#  {'label': 'Hooper Bay', 'value': 'Hooper Bay'},
#  {'label': 'Hot Springs', 'value': 'Hot Springs'},
#  {'label': 'Houston', 'value': 'Houston'},
#  {'label': 'Hughes', 'value': 'Hughes'},
#  {'label': 'Huntington', 'value': 'Huntington'},
#  {'label': 'Huntsville', 'value': 'Huntsville'},
#  {'label': 'Huron', 'value': 'Huron'},
#  {'label': 'Huslia', 'value': 'Huslia'},
#  {'label': 'Hydaburg', 'value': 'Hydaburg'},
#  {'label': 'Idaho Falls', 'value': 'Idaho Falls'},
#  {'label': 'Igiugig', 'value': 'Igiugig'},
#  {'label': 'Iliamna', 'value': 'Iliamna'},
#  {'label': 'Imperial', 'value': 'Imperial'},
#  {'label': 'Indianapolis', 'value': 'Indianapolis'},
#  {'label': 'International Falls', 'value': 'International Falls'},
#  {'label': 'Iron Mountain', 'value': 'Iron Mountain'},
#  {'label': 'Islip', 'value': 'Islip'},
#  {'label': 'Ithaca', 'value': 'Ithaca'},
#  {'label': 'Jacksn Hole', 'value': 'Jacksn Hole'},
#  {'label': 'Jackson', 'value': 'Jackson'},
#  {'label': 'Jacksonville', 'value': 'Jacksonville'},
#  {'label': 'Jacksonville NC', 'value': 'Jacksonville NC'},
#  {'label': 'Jamestown', 'value': 'Jamestown'},
#  {'label': 'Johnstown', 'value': 'Johnstown'},
#  {'label': 'Jonesboro', 'value': 'Jonesboro'},
#  {'label': 'Joplin', 'value': 'Joplin'},
#  {'label': 'Juneau', 'value': 'Juneau'},
#  {'label': 'Kahului', 'value': 'Kahului'},
#  {'label': 'Kalamazoo', 'value': 'Kalamazoo'},
#  {'label': 'Kalispell', 'value': 'Kalispell'},
#  {'label': 'Kalskag', 'value': 'Kalskag'},
#  {'label': 'Kaltag', 'value': 'Kaltag'},
#  {'label': 'Kamuela', 'value': 'Kamuela'},
#  {'label': 'Kansas City', 'value': 'Kansas City'},
#  {'label': 'Kenai', 'value': 'Kenai'},
#  {'label': 'Ketchikan', 'value': 'Ketchikan'},
#  {'label': 'Key West', 'value': 'Key West'},
#  {'label': 'Kiana', 'value': 'Kiana'},
#  {'label': 'Killeen', 'value': 'Killeen'},
#  {'label': 'King Cove', 'value': 'King Cove'},
#  {'label': 'King Salmon', 'value': 'King Salmon'},
#  {'label': 'Kipnuk', 'value': 'Kipnuk'},
#  {'label': 'Kirksville', 'value': 'Kirksville'},
#  {'label': 'Kivalina', 'value': 'Kivalina'},
#  {'label': 'Klamath Falls', 'value': 'Klamath Falls'},
#  {'label': 'Klawock', 'value': 'Klawock'},
#  {'label': 'Knoxville', 'value': 'Knoxville'},
#  {'label': 'Kobuk', 'value': 'Kobuk'},
#  {'label': 'Kodiak', 'value': 'Kodiak'},
#  {'label': 'Kona', 'value': 'Kona'},
#  {'label': 'Kongiganak', 'value': 'Kongiganak'},
#  {'label': 'Kotlik', 'value': 'Kotlik'},
#  {'label': 'Kotzebue', 'value': 'Kotzebue'},
#  {'label': 'Koyuk', 'value': 'Koyuk'},
#  {'label': 'Koyukuk', 'value': 'Koyukuk'},
#  {'label': 'Kwethluk', 'value': 'Kwethluk'},
#  {'label': 'Kwigillingok', 'value': 'Kwigillingok'},
#  {'label': 'La Crosse', 'value': 'La Crosse'},
#  {'label': 'Lafayette', 'value': 'Lafayette'},
#  {'label': 'Lahania-kapalua', 'value': 'Lahania-kapalua'},
#  {'label': 'Lake Charles', 'value': 'Lake Charles'},
#  {'label': 'Lanai', 'value': 'Lanai'},
#  {'label': 'Lancaster', 'value': 'Lancaster'},
#  {'label': 'Lansing', 'value': 'Lansing'},
#  {'label': 'Laramie', 'value': 'Laramie'},
#  {'label': 'Laredo', 'value': 'Laredo'},
#  {'label': 'Larsen Bay', 'value': 'Larsen Bay'},
#  {'label': 'Las Vegas', 'value': 'Las Vegas'},
#  {'label': 'Latrobe', 'value': 'Latrobe'},
#  {'label': 'Lawton', 'value': 'Lawton'},
#  {'label': 'Lebanon', 'value': 'Lebanon'},
#  {'label': 'Lewisburg', 'value': 'Lewisburg'},
#  {'label': 'Lewiston', 'value': 'Lewiston'},
#  {'label': 'Lexington KY', 'value': 'Lexington KY'},
#  {'label': 'Liberal', 'value': 'Liberal'},
#  {'label': 'Lihue', 'value': 'Lihue'},
#  {'label': 'Lincoln', 'value': 'Lincoln'},
#  {'label': 'Little Rock', 'value': 'Little Rock'},
#  {'label': 'Long Beach', 'value': 'Long Beach'},
#  {'label': 'Longview', 'value': 'Longview'},
#  {'label': 'Los Alamos', 'value': 'Los Alamos'},
#  {'label': 'Los Angeles', 'value': 'Los Angeles'},
#  {'label': 'Louisville', 'value': 'Louisville'},
#  {'label': 'Lubbock', 'value': 'Lubbock'},
#  {'label': 'Lynchburg', 'value': 'Lynchburg'},
#  {'label': 'MONTGOMERY', 'value': 'MONTGOMERY'},
#  {'label': 'Macon', 'value': 'Macon'},
#  {'label': 'Madison', 'value': 'Madison'},
#  {'label': 'Mammoth Lakes', 'value': 'Mammoth Lakes'},
#  {'label': 'Manchester NH', 'value': 'Manchester NH'},
#  {'label': 'Manhattan', 'value': 'Manhattan'},
#  {'label': 'Manistee', 'value': 'Manistee'},
#  {'label': 'Marion', 'value': 'Marion'},
#  {'label': 'Marshall', 'value': 'Marshall'},
#  {'label': 'Massena', 'value': 'Massena'},
#  {'label': 'McCook', 'value': 'McCook'},
#  {'label': 'Mcallen', 'value': 'Mcallen'},
#  {'label': 'Mcgrath', 'value': 'Mcgrath'},
#  {'label': 'Medford', 'value': 'Medford'},
#  {'label': 'Mekoryuk', 'value': 'Mekoryuk'},
#  {'label': 'Melbourne', 'value': 'Melbourne'},
#  {'label': 'Memphis', 'value': 'Memphis'},
#  {'label': 'Merced', 'value': 'Merced'},
#  {'label': 'Meridian', 'value': 'Meridian'},
#  {'label': 'Mesa', 'value': 'Mesa'},
#  {'label': 'Metakatla', 'value': 'Metakatla'},
#  {'label': 'Miami', 'value': 'Miami'},
#  {'label': 'Midland', 'value': 'Midland'},
#  {'label': 'Milwaukee', 'value': 'Milwaukee'},
#  {'label': 'Minneapolis', 'value': 'Minneapolis'},
#  {'label': 'Minot', 'value': 'Minot'},
#  {'label': 'Missoula', 'value': 'Missoula'},
#  {'label': 'Moab', 'value': 'Moab'},
#  {'label': 'Mobile', 'value': 'Mobile'},
#  {'label': 'Modesto', 'value': 'Modesto'},
#  {'label': 'Moline', 'value': 'Moline'},
#  {'label': 'Molokai', 'value': 'Molokai'},
#  {'label': 'Monroe', 'value': 'Monroe'},
#  {'label': 'Monterey', 'value': 'Monterey'},
#  {'label': 'Montrose CO', 'value': 'Montrose CO'},
#  {'label': 'Morgantown', 'value': 'Morgantown'},
#  {'label': 'Morristown', 'value': 'Morristown'},
#  {'label': 'Mountain Village', 'value': 'Mountain Village'},
#  {'label': 'Muscle Shoals', 'value': 'Muscle Shoals'},
#  {'label': 'Muskegon', 'value': 'Muskegon'},
#  {'label': 'Myrtle Beach', 'value': 'Myrtle Beach'},
#  {'label': 'Nantucket', 'value': 'Nantucket'},
#  {'label': 'Napakiak', 'value': 'Napakiak'},
#  {'label': 'Napaskiak', 'value': 'Napaskiak'},
#  {'label': 'Naples', 'value': 'Naples'},
#  {'label': 'Nashville', 'value': 'Nashville'},
#  {'label': 'Nelson Lagoon', 'value': 'Nelson Lagoon'},
#  {'label': 'New Bedford', 'value': 'New Bedford'},
#  {'label': 'New Bern', 'value': 'New Bern'},
#  {'label': 'New Haven', 'value': 'New Haven'},
#  {'label': 'New Orleans', 'value': 'New Orleans'},
#  {'label': 'New York', 'value': 'New York'},
#  {'label': 'Newark', 'value': 'Newark'},
#  {'label': 'Newburgh', 'value': 'Newburgh'},
#  {'label': 'Newport News', 'value': 'Newport News'},
#  {'label': 'Niagara Falls', 'value': 'Niagara Falls'},
#  {'label': 'Nightmute', 'value': 'Nightmute'},
#  {'label': 'Nikolai', 'value': 'Nikolai'},
#  {'label': 'Nikolski', 'value': 'Nikolski'},
#  {'label': 'Noatak', 'value': 'Noatak'},
#  {'label': 'Nome', 'value': 'Nome'},
#  {'label': 'Noorvik', 'value': 'Noorvik'},
#  {'label': 'Norfolk', 'value': 'Norfolk'},
#  {'label': 'North Bend', 'value': 'North Bend'},
#  {'label': 'North Platte', 'value': 'North Platte'},
#  {'label': 'Nuiqsut', 'value': 'Nuiqsut'},
#  {'label': 'Nulato', 'value': 'Nulato'},
#  {'label': 'Oakland', 'value': 'Oakland'},
#  {'label': 'Ogden', 'value': 'Ogden'},
#  {'label': 'Ogdensburg', 'value': 'Ogdensburg'},
#  {'label': 'Oklahoma City', 'value': 'Oklahoma City'},
#  {'label': 'Omaha', 'value': 'Omaha'},
#  {'label': 'Ontario', 'value': 'Ontario'},
#  {'label': 'Orlando', 'value': 'Orlando'},
#  {'label': 'Owensboro', 'value': 'Owensboro'},
#  {'label': 'PADUCAH', 'value': 'PADUCAH'},
#  {'label': 'PARKERSBURG', 'value': 'PARKERSBURG'},
#  {'label': 'Page', 'value': 'Page'},
#  {'label': 'Palm Springs', 'value': 'Palm Springs'},
#  {'label': 'Panama City', 'value': 'Panama City'},
#  {'label': 'Pasco', 'value': 'Pasco'},
#  {'label': 'Pellston', 'value': 'Pellston'},
#  {'label': 'Pendleton', 'value': 'Pendleton'},
#  {'label': 'Pensacola', 'value': 'Pensacola'},
#  {'label': 'Peoria', 'value': 'Peoria'},
#  {'label': 'Perryville', 'value': 'Perryville'},
#  {'label': 'Petersburg', 'value': 'Petersburg'},
#  {'label': 'Philadelphia', 'value': 'Philadelphia'},
#  {'label': 'Phoenix', 'value': 'Phoenix'},
#  {'label': 'Pierre', 'value': 'Pierre'},
#  {'label': 'Pittsburgh', 'value': 'Pittsburgh'},
#  {'label': 'Plattsburgh', 'value': 'Plattsburgh'},
#  {'label': 'Pocatello', 'value': 'Pocatello'},
#  {'label': 'Point Barrow', 'value': 'Point Barrow'},
#  {'label': 'Point Lay', 'value': 'Point Lay'},
#  {'label': 'Port Angeles', 'value': 'Port Angeles'},
#  {'label': 'Port Heiden', 'value': 'Port Heiden'},
#  {'label': 'Port Moller', 'value': 'Port Moller'},
#  {'label': 'Portland', 'value': 'Portland'},
#  {'label': 'Portsmouth', 'value': 'Portsmouth'},
#  {'label': 'Prescott', 'value': 'Prescott'},
#  {'label': 'Presque Isle', 'value': 'Presque Isle'},
#  {'label': 'Providence', 'value': 'Providence'},
#  {'label': 'Provincetown', 'value': 'Provincetown'},
#  {'label': 'Provo', 'value': 'Provo'},
#  {'label': 'Pueblo', 'value': 'Pueblo'},
#  {'label': 'Pullman', 'value': 'Pullman'},
#  {'label': 'Punta Gorda', 'value': 'Punta Gorda'},
#  {'label': 'Quincy', 'value': 'Quincy'},
#  {'label': 'Quinhagak', 'value': 'Quinhagak'},
#  {'label': 'Raleigh-durham', 'value': 'Raleigh-durham'},
#  {'label': 'Rapid City', 'value': 'Rapid City'},
#  {'label': 'Redding', 'value': 'Redding'},
#  {'label': 'Redmond-Bend', 'value': 'Redmond-Bend'},
#  {'label': 'Reno', 'value': 'Reno'},
#  {'label': 'Rhinelander', 'value': 'Rhinelander'},
#  {'label': 'Richmond', 'value': 'Richmond'},
#  {'label': 'Riverton WY', 'value': 'Riverton WY'},
#  {'label': 'Roanoke VA', 'value': 'Roanoke VA'},
#  {'label': 'Rochester', 'value': 'Rochester'},
#  {'label': 'Rock Springs', 'value': 'Rock Springs'},
#  {'label': 'Rockford', 'value': 'Rockford'},
#  {'label': 'Rockland', 'value': 'Rockland'},
#  {'label': 'Roswell', 'value': 'Roswell'},
#  {'label': 'Ruby', 'value': 'Ruby'},
#  {'label': 'Russian Mission', 'value': 'Russian Mission'},
#  {'label': 'Rutland', 'value': 'Rutland'},
#  {'label': 'Sacramento', 'value': 'Sacramento'},
#  {'label': 'Saginaw', 'value': 'Saginaw'},
#  {'label': 'Saint Cloud', 'value': 'Saint Cloud'},
#  {'label': 'Saint George', 'value': 'Saint George'},
#  {'label': 'Salina', 'value': 'Salina'},
#  {'label': 'Salisbury', 'value': 'Salisbury'},
#  {'label': 'Salt Lake City', 'value': 'Salt Lake City'},
#  {'label': 'San Angelo', 'value': 'San Angelo'},
#  {'label': 'San Antonio', 'value': 'San Antonio'},
#  {'label': 'San Diego', 'value': 'San Diego'},
#  {'label': 'San Francisco', 'value': 'San Francisco'},
#  {'label': 'San Jose', 'value': 'San Jose'},
#  {'label': 'San Luis Obispo', 'value': 'San Luis Obispo'},
#  {'label': 'Sand Point', 'value': 'Sand Point'},
#  {'label': 'Sanford', 'value': 'Sanford'},
#  {'label': 'Santa Ana', 'value': 'Santa Ana'},
#  {'label': 'Santa Barbara', 'value': 'Santa Barbara'},
#  {'label': 'Santa Fe', 'value': 'Santa Fe'},
#  {'label': 'Santa Maria', 'value': 'Santa Maria'},
#  {'label': 'Santa Rosa', 'value': 'Santa Rosa'},
#  {'label': 'Saranac Lake', 'value': 'Saranac Lake'},
#  {'label': 'Sarasota', 'value': 'Sarasota'},
#  {'label': 'Sault Ste Marie', 'value': 'Sault Ste Marie'},
#  {'label': 'Savannah', 'value': 'Savannah'},
#  {'label': 'Savoonga', 'value': 'Savoonga'},
#  {'label': 'Scammon Bay', 'value': 'Scammon Bay'},
#  {'label': 'Scottsbluff', 'value': 'Scottsbluff'},
#  {'label': 'Scranton', 'value': 'Scranton'},
#  {'label': 'Seattle', 'value': 'Seattle'},
#  {'label': 'Selawik', 'value': 'Selawik'},
#  {'label': 'Shageluk', 'value': 'Shageluk'},
#  {'label': 'Shaktoolik', 'value': 'Shaktoolik'},
#  {'label': 'Sheridan', 'value': 'Sheridan'},
#  {'label': 'Shishmaref', 'value': 'Shishmaref'},
#  {'label': 'Show Low', 'value': 'Show Low'},
#  {'label': 'Shreveport', 'value': 'Shreveport'},
#  {'label': 'Shungnak', 'value': 'Shungnak'},
#  {'label': 'Sidney', 'value': 'Sidney'},
#  {'label': 'Sioux City', 'value': 'Sioux City'},
#  {'label': 'Sioux Falls', 'value': 'Sioux Falls'},
#  {'label': 'Sitka', 'value': 'Sitka'},
#  {'label': 'Skagway', 'value': 'Skagway'},
#  {'label': 'Sleetmute', 'value': 'Sleetmute'},
#  {'label': 'South Bend', 'value': 'South Bend'},
#  {'label': 'South Naknek', 'value': 'South Naknek'},
#  {'label': 'Spokane', 'value': 'Spokane'},
#  {'label': 'Springfield', 'value': 'Springfield'},
#  {'label': "St Mary's", 'value': "St Mary's"},
#  {'label': 'St. Augustine Airport', 'value': 'St. Augustine Airport'},
#  {'label': 'St. Louis', 'value': 'St. Louis'},
#  {'label': 'St. Michael', 'value': 'St. Michael'},
#  {'label': 'St. Paul Island', 'value': 'St. Paul Island'},
#  {'label': 'St. Petersburg', 'value': 'St. Petersburg'},
#  {'label': 'State College Pennsylvania',
#   'value': 'State College Pennsylvania'},
#  {'label': 'Stockton', 'value': 'Stockton'},
#  {'label': 'Syracuse', 'value': 'Syracuse'},
#  {'label': 'Tallahassee', 'value': 'Tallahassee'},
#  {'label': 'Tampa', 'value': 'Tampa'},
#  {'label': 'Tatalina', 'value': 'Tatalina'},
#  {'label': 'Teller', 'value': 'Teller'},
#  {'label': 'Teterboro', 'value': 'Teterboro'},
#  {'label': 'Texarkana', 'value': 'Texarkana'},
#  {'label': 'Thief River Falls', 'value': 'Thief River Falls'},
#  {'label': 'Tin City', 'value': 'Tin City'},
#  {'label': 'Togiak Village', 'value': 'Togiak Village'},
#  {'label': 'Toksook Bay', 'value': 'Toksook Bay'},
#  {'label': 'Toledo', 'value': 'Toledo'},
#  {'label': 'Topeka', 'value': 'Topeka'},
#  {'label': 'Traverse City', 'value': 'Traverse City'},
#  {'label': 'Trenton', 'value': 'Trenton'},
#  {'label': 'Tucson', 'value': 'Tucson'},
#  {'label': 'Tulsa', 'value': 'Tulsa'},
#  {'label': 'Tupelo', 'value': 'Tupelo'},
#  {'label': 'Twin Falls', 'value': 'Twin Falls'},
#  {'label': 'Tyler', 'value': 'Tyler'},
#  {'label': 'Unalakleet', 'value': 'Unalakleet'},
#  {'label': 'Unalaska', 'value': 'Unalaska'},
#  {'label': 'Vail', 'value': 'Vail'},
#  {'label': 'Valdez', 'value': 'Valdez'},
#  {'label': 'Valdosta', 'value': 'Valdosta'},
#  {'label': 'Valparaiso', 'value': 'Valparaiso'},
#  {'label': 'Venetie', 'value': 'Venetie'},
#  {'label': 'Vernal', 'value': 'Vernal'},
#  {'label': 'Victoria', 'value': 'Victoria'},
#  {'label': 'Vineyard Haven MA', 'value': 'Vineyard Haven MA'},
#  {'label': 'Visalia', 'value': 'Visalia'},
#  {'label': 'Waco', 'value': 'Waco'},
#  {'label': 'Wainwright', 'value': 'Wainwright'},
#  {'label': 'Wales', 'value': 'Wales'},
#  {'label': 'Walla Walla', 'value': 'Walla Walla'},
#  {'label': 'Washington', 'value': 'Washington'},
#  {'label': 'Wassau', 'value': 'Wassau'},
#  {'label': 'Waterloo', 'value': 'Waterloo'},
#  {'label': 'Watertown', 'value': 'Watertown'},
#  {'label': 'Wenatchee', 'value': 'Wenatchee'},
#  {'label': 'West Palm Beach', 'value': 'West Palm Beach'},
#  {'label': 'Weyers Cave', 'value': 'Weyers Cave'},
#  {'label': 'White Mountain', 'value': 'White Mountain'},
#  {'label': 'White Plains', 'value': 'White Plains'},
#  {'label': 'Wichita', 'value': 'Wichita'},
#  {'label': 'Wichita Falls', 'value': 'Wichita Falls'},
#  {'label': 'Williamsport', 'value': 'Williamsport'},
#  {'label': 'Williston', 'value': 'Williston'},
#  {'label': 'Wilmington', 'value': 'Wilmington'},
#  {'label': 'Windsor Locks', 'value': 'Windsor Locks'},
#  {'label': 'Wolf Point', 'value': 'Wolf Point'},
#  {'label': 'Worcester', 'value': 'Worcester'},
#  {'label': 'Worland', 'value': 'Worland'},
#  {'label': 'Wrangell', 'value': 'Wrangell'},
#  {'label': 'Yakima', 'value': 'Yakima'},
#  {'label': 'Yakutat', 'value': 'Yakutat'},
#  {'label': 'Youngstown', 'value': 'Youngstown'},
#  {'label': 'Yuma', 'value': 'Yuma'}]

# %%
#============================================== Layout ==============================================#

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.CERULEAN])

layout = dict(
    autosize=True,
    automargin=True,
    margin=dict(l=30, r=30, b=20, t=40),
    hovermode="closest",
    plot_bgcolor="#F9F9F9",
    paper_bgcolor="#F9F9F9",
    legend=dict(font=dict(size=10), orientation="h"),
    title="Map",
    mapbox=dict(
        accesstoken = 'pk.eyJ1Ijoieml5dXQiLCJhIjoiY2toNGFqamtwMDR6ZDM0cWg0MzJ3NWxyMiJ9.bH9W0iiVgZMF_s5VyeoZ4g',
        style="light",
        center=dict(lon=-95, lat=39.5),
        zoom=3.5,
    ),
)

# Component of input group

controls = dbc.Card(
    [
        dbc.FormGroup(
            [
                dbc.Label("Start City"),
                dcc.Dropdown(
                    options=[{"label":i,"value":i}for i in df.Source_City.unique()],
                    value = 'Choose a start city',
                    id="departure_select",
                ),
            ]
        ),
        dbc.FormGroup(
            [
                dbc.Label("Destination City"),
                dcc.Dropdown(
                    #options=[{"label":i,"value":i} for i in df.Destination_City.unique()],
                    #value="Choose a destination city",
                    id="arrival_select",
                ),
            ]
        ),
        dbc.FormGroup(
            [
                dbc.Label("Start Airport"),
                dcc.Dropdown(
                    id="departure_airport_options"
                ),
            ]
        ),
        dbc.FormGroup(
            [
                dbc.Label("Destination Airport"),
                dcc.Dropdown(
                    id="arrival_airport_options"
                ),
            ]
        ),
        dbc.Button("Submit", outline=False, color="primary", className="mr-1",id='submit-button-state',n_clicks = 0),
    ],
    body=True,
)


# Component of source city info

first_card = dbc.Card(
        [html.Div(id='source-city-image'),
        dbc.CardBody(
        [
            html.H5(html.Div(id='display-source-city-name'),
                style={
                      'textAlign': 'left',
                      'color': '#173F5F',
                      'fontSize': 25
                }),
            html.P(html.Div(id='display-source-city-info')),
            html.Div(id='display-source-city-link')
            #dbc.Button("Go to see city info", color="primary"),
        ]
    )
      ]
)

# Component of destination city info

second_card = dbc.Card(
    [html.Div(id='arrival-city-image'),
    dbc.CardBody(
        [
            html.H5(html.Div(id='display-arrival-city-name'),
                style={
                      'textAlign': 'left',
                      'color': '#173F5F',
                      'fontSize': 25
                }),
            html.P(html.Div(id='display-arrival-city-info')),
            html.Div(id='display-destination-city-link')
            #dbc.Button("Go to see city info", color="primary"),
        ]
    )
    ]
)

# Layout of overall web application 

app.layout = dbc.Container(
    [
        dbc.Row(
            dbc.Col(html.H1("Kartemap - An Airport Network Analysis Application"))
        ),
        
        dbc.Row(
            dbc.Col(html.P("Make your air trip fast and easy!"),
                    style={
                      'textAlign': 'left',
                      'color': '#173F5F',
                      'fontSize': 25
                })
        ),
        
        dbc.Row(
            [
                dbc.Col(controls, md=3),
                dbc.Col(dcc.Graph(id="map"), md=9),
                dcc.Store(id='memory-output_route'),
                dcc.Store(id='memory-output_distance')
            ],
            align="center",
        ),
        
        html.Br(),
        
        dbc.Row(
            dbc.Col(
                dbc.Card(
                          dbc.CardBody(html.Div(id='display-selected-values'),
                style={
                      'textAlign': 'left',
                      'color': '#173F5F',
                      'fontSize': 18
                }),
                          color="secondary", inverse=True, className="mb-3",
        )
                
            )
        ),
        
        html.Br(),
        
        dbc.Row([dbc.Col(first_card, width=6), dbc.Col(second_card, width=6)])
    ],
    
    id="main-container",
    style={"display": "flex", "flex-direction": "column"},
    fluid=True
)
  
#============================================== Callbacks ==============================================#
    
# callback of airport according to the city input
@app.callback(
    Output('arrival_select', 'options'),
    [Input('departure_select', 'value')])
def set_arrival_select_options(selected_departure_city):
    arrival_city_list = df.Destination_City.unique().tolist()
    arrival_city_list.remove(selected_departure_city)
    return [{'label': i, 'value': i} for i in arrival_city_list]


@app.callback(
    Output('departure_airport_options', 'options'),
    [Input('departure_select', 'value')])
def set_departure_airport_options(selected_departure_city):
    return [{'label': i, 'value': i} for i in departure_airport_dict[selected_departure_city]]


@app.callback(
    Output('departure_airport_options', 'value'),
    [Input('departure_airport_options', 'options')])
def set_departure_airport_value(available_departure_options):
    return available_departure_options[0]['value']


@app.callback(
    Output('arrival_airport_options', 'options'),
    [Input('arrival_select', 'value')])
def set_arrival_airport_options(selected_arrival_city):
    return [{'label': i, 'value': i} for i in arrival_airport_dict[selected_arrival_city]]


@app.callback(
    Output('arrival_airport_options', 'value'),
    [Input('arrival_airport_options', 'options')])
def set_arrival_airport_value(available_arrival_options):
    return available_arrival_options[0]['value']
    

    
## callback of the shorest route and the distance
# route:
@app.callback(
    Output(component_id="memory-output_route",component_property="data"),
    [Input(component_id="departure_airport_options",component_property="value"),
     Input(component_id="arrival_airport_options", component_property="value"),
    ])

def shortest_path(initial, end):
    network = Network()
    network.add_nodes(cities)
    for connection in distances.items():
        frm = cities[connection[0]]
        for connection_to in connection[1].items():
            network.add_edge(frm, cities[connection_to[0]], connection_to[1])


    start_city_index = cities.index(initial)
    start_city = network.get_nodes()[start_city_index]


    Dijkstra.compute(network, network.get_node(start_city))

    target_city = network.get_node(end)
    path = [target_city.get_name()]
    Dijkstra.compute_shortest_path(target_city, path)
    route = path[::-1]
    return route

# distance
@app.callback(
    Output(component_id="memory-output_distance",component_property="data"),
    [Input(component_id="departure_airport_options",component_property="value"),
     Input(component_id="arrival_airport_options", component_property="value"),
    ])

def shortest_path(initial, end):
    network = Network()
    network.add_nodes(cities)
    for connection in distances.items():
        frm = cities[connection[0]]
        for connection_to in connection[1].items():
            network.add_edge(frm, cities[connection_to[0]], connection_to[1])


    start_city_index = cities.index(initial)
    start_city = network.get_nodes()[start_city_index]


    Dijkstra.compute(network, network.get_node(start_city))

    target_city = network.get_node(end)
    path = [target_city.get_name()]
    Dijkstra.compute_shortest_path(target_city, path)
    distance = round(target_city.get_weight(),2)
    return distance

# callback of map

default_map = go.Figure(go.Scattermapbox())
default_map.update_layout(
        margin ={'l':0,'t':0,'b':0,'r':0},
        mapbox = {
                  'accesstoken': 'pk.eyJ1Ijoieml5dXQiLCJhIjoiY2toNGFqamtwMDR6ZDM0cWg0MzJ3NWxyMiJ9.bH9W0iiVgZMF_s5VyeoZ4g',
                  'style': "outdoors", 
                  'center': {'lon': -95, 'lat': 39.5},
                  'zoom': 3.5},
        showlegend = False)


@app.callback(Output('map', 'figure'),
            [Input('submit-button-state','n_clicks')],
            [State('departure_airport_options', 'value'),
             State('arrival_airport_options', 'value'),
             State("memory-output_route","data")])

def update_figure(n_clicks,departure_select,arrival_select,path):            
    if n_clicks:
        lat_list = []
        lon_list = []

        for i in path:
            lat_list.append(list(df_airport.loc[df_airport.Airport==i].Latitude)[0])
            lon_list.append(list(df_airport.loc[df_airport.Airport==i].Longitude)[0])
        
        marker_list = ['circle'] * len(path)
        text_list = [''] * len(path)
        marker_list[0] = 'airport'
        marker_list[-1] = 'star'
    
        for i in range(0,len(path)):
            text_list[i] = list(df_airport.loc[df_airport.Airport==path[i]].City)[0]
        text_list[0] = 'Departure'
        text_list[-1] = 'Arrival'
    
        fig = go.Figure(go.Scattermapbox(
        mode =  "markers+text+lines",
        lat = lat_list,
        lon = lon_list,
        marker = {'size': 10, 'symbol': marker_list},
        text = text_list,textposition = "bottom right"))
    
        fig.update_layout(
        margin ={'l':0,'t':0,'b':0,'r':0},
        mapbox = {
                  'accesstoken': 'pk.eyJ1Ijoieml5dXQiLCJhIjoiY2toNGFqamtwMDR6ZDM0cWg0MzJ3NWxyMiJ9.bH9W0iiVgZMF_s5VyeoZ4g',
                  'style': "outdoors", 
                  'center': {'lon': -95, 'lat': 39.5},
                  'zoom': 3.5},
        showlegend = False)

        return fig
    else:
        return default_map

# callback of sentence

@app.callback(Output('display-selected-values', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('departure_select', 'value'),
             State('arrival_select', 'value'),
             State('memory-output_distance','data')])

def set_display_children(n_clicks,selected_start, selected_arrival,distance):
    if n_clicks:
        return u'The shortest airline route from {} to {} is {} KM.'.format(selected_start, selected_arrival,distance)
    

# callback of source/arrival city name, info, image, and link
@app.callback(Output('display-source-city-name', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('departure_select', 'value')])

def display_source_city_name(n_clicks,selected_start):
    if n_clicks:
        return selected_start

@app.callback(Output('display-source-city-info', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('departure_select', 'value')])

def display_source_city_info(n_clicks,selected_start):
    if n_clicks:
        source_population = list(df_city.loc[df_city.City==selected_start].Population)[0]
        return u'The population of {} is {}.'.format(selected_start, source_population)

    
    
@app.callback(Output('display-arrival-city-name', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('arrival_select', 'value')])

def display_source_city_name(n_clicks,selected_arrival):
    if n_clicks:
        return selected_arrival

@app.callback(Output('display-arrival-city-info', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('arrival_select', 'value')])

def display_source_city_info(n_clicks,selected_arrival):
    if n_clicks:
        arrival_population = list(df_city.loc[df_city.City==selected_arrival].Population)[0]
        return u'The population of {} is {}.'.format(selected_arrival, arrival_population)
    

    
    
@app.callback(Output('source-city-image', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('departure_select', 'value')])

def display_source_city_image(n_clicks,selected_start):
    if n_clicks:
        source_city_image = list(df_city.loc[df_city.City==selected_start].photo_link)[0]
        return dbc.CardImg(src=source_city_image, top=True)

    
@app.callback(Output('arrival-city-image', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('arrival_select', 'value')])

def display_source_city_image(n_clicks,selected_arrival):
    if n_clicks:
        arrival_city_image = list(df_city.loc[df_city.City==selected_arrival].photo_link)[0]
        return dbc.CardImg(src=arrival_city_image, top=True)



@app.callback(Output('display-source-city-link', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('departure_select', 'value')])

def display_source_city_link(n_clicks,selected_start):
    if n_clicks:
        source_city_link = list(df_city.loc[df_city.City==selected_start].Links)[0]
        return dbc.CardLink('Go to explore city info', href = source_city_link,target = 'blank')

    
@app.callback(Output('display-destination-city-link', 'children'),
            [Input('submit-button-state','n_clicks')],
            [State('arrival_select', 'value')])

def display_source_city_link(n_clicks,selected_arrival):
    if n_clicks:
        arrival_city_link = list(df_city.loc[df_city.City==selected_arrival].Links)[0]
        return dbc.CardLink('Go to explore city info', href = arrival_city_link,target = 'blank')
    
    
    

if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False,dev_tools_ui=False,dev_tools_props_check=False,\
                   port=8050, host='127.0.0.1')
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
